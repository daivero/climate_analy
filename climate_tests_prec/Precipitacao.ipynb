# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.9 MB/s eta 0:00:0000:01
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
precipitacao=pd.read_excel('https://portal.inmet.gov.br/uploads/normais/Normal-Climatologica-PREC.xlsx',skiprows=2)
precipitacao
# Out:
#      Código        Nome da Estação  UF Janeiro Fevereiro  Março  Abril   Maio  \
# 0      82989           AGUA BRANCA  AL    48.6         -   85.7     80  133.2
# 1      83249            ALAGOINHAS  BA    54.6        60   61.7  121.5  157.4
# 2      82353              ALTAMIRA  PA   284.7     330.3  399.5  365.6  232.9
# 3      83007     ALTO DA BOA VISTA  RJ   228.6     177.8    252  201.1  180.8
# 4      82970         ALTO PARNAIBA  MA     231     195.7  241.6  128.4   39.6
# ..       ...                   ...  ..     ...       ...    ...    ...    ...
# 216    83642                VICOSA  MG     236     116.9  163.3     58   34.2
# 217    83648               VITORIA  ES   131.2      79.4  139.5  122.9   92.4
# 218    83344  VITORIA DA CONQUISTA  BA    96.3      76.6   97.5   53.8   24.9
# 219    83623           VOTUPORANGA  SP   288.3     197.6  148.2   66.3     56
# 220    82376               ZE DOCA  MA   255.2     321.8  348.5  342.2  202.6
#
#      Junho  Julho Agosto Setembro Outubro Novembro Dezembro     Ano
# 0    160.4  170.1     96     52.2    35.8     27.7     39.9       -
# 1    144.3  110.4   91.5     66.3    51.3     60.2     53.2  1032.4
# 2    102.9      -   34.2     46.2      58     90.5      164       -
# 3    154.1  179.9  150.5    219.5   194.7      239    236.8  2414.8
# 4      2.5    0.4      2     14.1    74.8    163.8    186.3  1280.2
# ..     ...    ...    ...      ...     ...      ...      ...     ...
# 216   15.5    7.7   10.4     49.7    99.2    204.8    265.9  1261.6
# 217     70   67.5   59.9     63.1   123.9    233.6      201  1384.4
# 218   25.3     28     19     19.4    42.8    127.8    117.5   728.9
# 219   30.5   15.5   18.7     62.3    94.5    147.2      192  1317.1
# 220   85.6   40.4   16.2     16.9    23.1     51.4    106.4  1810.3
#
# [221 rows x 16 columns]

# %%
precipitacao.describe()
# Out:
#             Código
# count    221.000000
# mean   83171.253394
# std      536.173835
# min    82024.000000
# 25%    82765.000000
# 50%    83286.000000
# 75%    83587.000000
# max    83997.000000

# %%
precipitacao.columns
# Out:
# Index(['Código ', 'Nome da Estação', 'UF', 'Janeiro', 'Fevereiro', 'Março',
#        'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro',
#        'Novembro', 'Dezembro', 'Ano'],
#       dtype='object')

# %%
import numpy as np
precipitacao[['UF', 'Janeiro', 'Fevereiro', 'Março',
       'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro',
       'Novembro', 'Dezembro']].replace('-', np.nan)
# Out:
#      UF  Janeiro  Fevereiro  Março  Abril   Maio  Junho  Julho  Agosto  \
# 0    AL     48.6        NaN   85.7   80.0  133.2  160.4  170.1    96.0
# 1    BA     54.6       60.0   61.7  121.5  157.4  144.3  110.4    91.5
# 2    PA    284.7      330.3  399.5  365.6  232.9  102.9    NaN    34.2
# 3    RJ    228.6      177.8  252.0  201.1  180.8  154.1  179.9   150.5
# 4    MA    231.0      195.7  241.6  128.4   39.6    2.5    0.4     2.0
# ..   ..      ...        ...    ...    ...    ...    ...    ...     ...
# 216  MG    236.0      116.9  163.3   58.0   34.2   15.5    7.7    10.4
# 217  ES    131.2       79.4  139.5  122.9   92.4   70.0   67.5    59.9
# 218  BA     96.3       76.6   97.5   53.8   24.9   25.3   28.0    19.0
# 219  SP    288.3      197.6  148.2   66.3   56.0   30.5   15.5    18.7
# 220  MA    255.2      321.8  348.5  342.2  202.6   85.6   40.4    16.2
#
#      Setembro  Outubro  Novembro  Dezembro
# 0        52.2     35.8      27.7      39.9
# 1        66.3     51.3      60.2      53.2
# 2        46.2     58.0      90.5     164.0
# 3       219.5    194.7     239.0     236.8
# 4        14.1     74.8     163.8     186.3
# ..        ...      ...       ...       ...
# 216      49.7     99.2     204.8     265.9
# 217      63.1    123.9     233.6     201.0
# 218      19.4     42.8     127.8     117.5
# 219      62.3     94.5     147.2     192.0
# 220      16.9     23.1      51.4     106.4
#
# [221 rows x 13 columns]

# %%
prec=precipitacao[['UF', 'Janeiro', 'Fevereiro', 'Março',
       'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro',
       'Novembro', 'Dezembro']].replace('-', np.nan).groupby("UF").mean()#.mean(axis=0)

# %%
prec
# Out:
#        Janeiro   Fevereiro       Março       Abril        Maio       Junho  \
# UF
# AC  301.350000  284.200000  312.250000  203.550000  118.000000   59.550000
# AL   61.033333   72.400000  103.600000  137.225000  202.000000  229.775000
# AM  293.909091  284.890909  323.172727  307.809091  252.127273  157.200000
# AP  268.100000  369.300000  400.100000  376.400000  308.400000  252.400000
# BA  101.913636   87.230435  111.359091   88.682609   62.591304   55.591304
# CE  125.566667  141.100000  216.200000  199.555556  114.788889   61.811111
# DF  206.000000  179.500000  226.000000  145.200000   26.900000    3.300000
# ES  141.250000  100.650000  150.450000  109.725000   66.675000   49.600000
# GO  261.411111  222.622222  234.488889  108.488889   28.311111    9.011111
# MA  231.533333  253.925000  316.691667  261.250000  149.283333   56.633333
# MG  226.932500  148.204762  165.830952   61.921951   29.890244   11.958537
# MS  228.750000  172.800000  159.400000   71.350000   55.950000   23.750000
# MT  274.300000  270.971429  248.871429  117.483333   36.971429   13.333333
# PA  282.169231  334.369231  394.000000  352.915385  249.700000  131.630769
# PB   81.550000  102.025000  146.325000  148.950000  156.175000  230.366667
# PE   75.450000   78.400000  108.142857   95.900000   98.514286  124.266667
# PI  154.762500  169.810000  192.211111  157.570000   73.580000   24.950000
# PR  245.316667  210.033333  170.580000  111.916667  114.483333  114.250000
# RJ  212.420000  131.327273  160.600000   85.736364   63.663636   38.754545
# RN   81.400000   99.166667  168.075000  181.425000  134.150000  160.700000
# RR   44.550000   40.250000   66.500000  180.650000  343.150000  350.150000
# RS  145.993333  145.007143  128.585714  140.120000  131.433333  131.080000
# SC  209.933333  184.766667  148.000000  130.283333  136.000000  137.783333
# SE   53.200000   53.900000   70.033333  122.033333  188.066667  172.800000
# SP  286.633333  213.100000  177.028571   74.442857   59.400000   36.157143
# TO  271.550000  238.283333  261.466667  172.000000   54.783333    7.183333
#
#          Julho      Agosto    Setembro     Outubro    Novembro    Dezembro
# UF
# AC   37.950000   62.950000  107.250000  162.800000  231.100000  277.400000
# AL  201.250000  132.625000   71.300000   45.550000   31.100000   33.066667
# AM  124.270000   96.836364  115.527273  159.418182  200.927273  261.863636
# AP  203.900000   96.300000   25.400000   22.700000   58.100000  144.600000
# BA   51.268182   36.000000   31.708696   54.031818  118.591304  110.860870
# CE   41.083333   13.037500    6.177778   10.777778   13.544444   36.855556
# DF    1.500000   16.300000   38.100000  141.800000  253.100000  241.100000
# ES   50.975000   45.625000   55.450000  108.225000  221.875000  208.700000
# GO    3.000000    8.144444   37.477778  118.944444  214.966667  264.900000
# MA   33.583333   12.191667   15.458333   45.316667   85.341667  125.016667
# MG    7.587805    9.983333   37.448780   90.058537  202.860000  254.373171
# MS   14.100000   18.550000   52.650000   93.700000  142.200000  186.250000
# MT    6.171429   10.542857   52.300000  146.842857  208.528571  260.714286
# PA  100.163636   53.600000   45.700000   64.315385   99.946154  159.092308
# PB  200.250000   82.050000   41.375000   19.550000   16.525000   39.333333
# PE   92.485714   58.057143   28.214286   20.128571   26.114286   44.657143
# PI   12.111111    3.610000    6.720000   29.430000   58.650000   86.990000
# PR   94.033333   72.666667  136.850000  172.300000  150.700000  185.216667
# RJ   43.560000   37.754545   74.627273  102.227273  195.781818  225.372727
# RN  117.900000   51.325000   24.400000   11.525000   13.375000   25.100000
# RR  313.400000  215.900000  121.800000   80.700000   80.200000   60.400000
# RS  140.466667  116.860000  142.613333  182.866667  125.886667  141.893333
# SC  149.783333  122.716667  179.350000  205.583333  149.383333  167.966667
# SE  143.200000   93.566667   63.600000   48.733333   34.566667   24.866667
# SP   26.814286   23.714286   66.457143  118.714286  160.085714  228.285714
# TO    2.166667    3.216667   37.783333  118.166667  210.200000  242.800000

# %%
for idx, row in prec.iterrows():
    average=row.mean()
    prec.at[idx,'prec']=average

# %%
prec['prec'].to_dict()
# Out:
# {'AC': 179.8625,
#  'AL': 110.07708333333332,
#  'AM': 214.8293181818182,
#  'AP': 210.47499999999997,
#  'BA': 75.81910408432147,
#  'CE': 81.70821759259259,
#  'DF': 123.23333333333333,
#  'ES': 109.1,
#  'GO': 125.98055555555554,
#  'MA': 132.18541666666664,
#  'MG': 103.92088100077429,
#  'MS': 101.62083333333334,
#  'MT': 137.25257936507936,
#  'PA': 188.96684149184148,
#  'PB': 105.37291666666667,
#  'PE': 70.86091269841269,
#  'PI': 80.86622685185185,
#  'PR': 148.19555555555556,
#  'RJ': 114.31878787878789,
#  'RN': 89.04513888888889,
#  'RR': 158.1375,
#  'RS': 139.40051587301588,
#  'SC': 160.12916666666663,
#  'SE': 89.04722222222222,
#  'SP': 122.56944444444443,
#  'TO': 134.96666666666667}

# %%
prec_dict=prec['prec'].to_dict()

# %%
import geopandas as gpd

# Make sure the path to the shapefile is correct
shapefile_path = 'BRA_adm1.shp'
gdf_brazil = gpd.read_file(shapefile_path)

# %%
for idx, row in gdf_brazil.iterrows():
    state=row['HASC_1'].replace('BR.','')
    if state in prec_dict:
        prec_for_state=prec_dict[state]
        gdf_brazil.at[idx,'prec']=prec_for_state

# %%
gdf_brazil.plot(column='prec')
# Out:
# <Axes: >
